# %% [markdown]
# Continuation of prev notebook

# %% [markdown]
# ### MODEL SEGMENTATION

# %% [markdown]
# we will make 2 models. one for age>=25 i.e the older population for whom we got less error. Another for the younger popoulation, where we'll change our assumptions and parameters to reduce the error

# %%
import pandas as pd
import numpy as np
import openpyxl
import matplotlib.pyplot as plt
import seaborn as sns
df= pd.read_excel(r"C:\vs code programming\.vscode\NewCfile\Codebasics_ML\premium_project\premiums.xlsx")
df.shape
# Out:
# (50000, 13)

# %%
df.Age.describe()
# Out:
# count    50000.000000
# mean        34.593480
# std         15.000437
# min         18.000000
# 25%         22.000000
# 50%         31.000000
# 75%         45.000000
# max        356.000000
# Name: Age, dtype: float64

# %%
df_young = df[df.Age<=25]
df_rest = df[df.Age>25]

# %%
df_young.shape, df_rest.shape
# Out:
# ((20096, 13), (29904, 13))

# %%
df_young.to_excel("premiums_young.xlsx", index=False)
df_rest.to_excel("premiums_rest.xlsx", index=False)

# %% [markdown]
# Now, we got a new dataset named premium_young_with_gr

# %%
import pandas as pd
df_gr = pd.read_excel(r"C:\vs code programming\.vscode\NewCfile\Codebasics_ML\premium_project\premiums_young_with_gr.xlsx")
df_gr.head()
# Out:
#    Age  Gender     Region Marital_status  Number Of Dependants BMI_Category  \
# 0   18    Male  Northeast      Unmarried                     0   Overweight
# 1   22  Female  Northwest      Unmarried                     0  Underweight
# 2   21  Female  Southeast      Unmarried                     0       Normal
# 3   25    Male  Southeast      Unmarried                     0       Normal
# 4   20    Male  Southeast      Unmarried                     2   Overweight
#
#   Smoking_Status Employment_Status Income_Level  Income_Lakhs  \
# 0        Regular     Self-Employed        > 40L            99
# 1     No Smoking        Freelancer         <10L             3
# 2        Regular          Salaried        > 40L            97
# 3     No Smoking        Freelancer    10L - 25L            15
# 4     No Smoking        Freelancer    10L - 25L            14
#
#        Medical History Insurance_Plan  Annual_Premium_Amount  Genetical_Risk
# ...

# %% [markdown]
# Here we have a column named genetical risk. we will be using this column to make analysis for age<25 in order the remove the previously observed error margin
